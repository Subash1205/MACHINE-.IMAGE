# %%
pip install 1OS
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
import warnings
warnings.simplefilter('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as  plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
WillSmith = os.listdir("C:\\Users\\Admin\\Documents\\SUBASH Bsc(AI) II year SEM 4\\archive\\Will Smith")

# %%
HughJackman = os.listdir("C:\\Users\\Admin\\Documents\\SUBASH Bsc(AI) II year SEM 4\\archive\\Hugh Jackman")

# %%
MeganFox = os.listdir("C:\\Users\Admin\Documents\\SUBASH Bsc(AI) II year SEM 4\\archive\\Megan Fox")

# %%
limit=10
WillSmith_img = [None]*limit
j=0
for i in WillSmith:
    if(j<limit):
        WillSmith_img[j] = imread("C:\\Users\\Admin\\Documents\\SUBASH Bsc(AI) II year SEM 4\\archive\\Will Smith\\"+i)
        j+=1
    else:
        break

# %%
limit=10
HughJackman_img = [None]*limit
j=0
for i in HughJackman:
    if(j<limit):
        HughJackman_img[j] = imread("C:\\Users\\Admin\\Documents\\SUBASH Bsc(AI) II year SEM 4\\archive\\Hugh Jackman\\"+i)
        j+=1
    else:
        break

# %%
limit=10
MeganFox_img=[None]*limit
j=0
for i in MeganFox:
    if(j<limit):
        MeganFox_img[j]=imread("C:\\Users\Admin\Documents\\SUBASH Bsc(AI) II year SEM 4\\archive\\Megan Fox\\"+i)
        j+=1
    else:
        break

# %%
imshow(WillSmith_img[0])

# %%
imshow(MeganFox_img[2])

# %%
imshow(HughJackman_img[3])

# %% [markdown]
# # B-3 GRAY RGB2

# %%
WillSmith_gray=[None]*limit
j=0
for i in WillSmith:
    if(j<limit):
        WillSmith_gray[j]=rgb2gray(WillSmith_img[j])
        j+=1
    else:
        break

# %%
MeganFox_gray=[None]*limit
j=0
for i in MeganFox:
    if(j<limit):
        MeganFox_gray[j]=rgb2gray(MeganFox_img[j])
        j+=1
    else:
        break

# %%
HughJackman_gray = [None]*limit
j=0
for i in HughJackman:
    if(j<limit):
        HughJackman_gray[j] = rgb2gray(HughJackman_img[j][:,:,:3])
        j+=1
    else:
        break

# %%
for j in range (10):
    lm = WillSmith_gray[j]
    WillSmith_gray[j]=resize(lm,(512,512))

# %%
for j in range (10):
    pm = HughJackman_gray[j]
    HughJackman_gray[j] = resize(pm,(512,512))

# %%
for j in range (10):
    db = MeganFox_gray[j]
    MeganFox_gray[j] = resize(db,(512,512))

# %%
WillSmith_gray[0].shape
# Out:
# (512, 512)

# %%
imshow(WillSmith_gray[0])

# %%
imshow(MeganFox_gray[2])

# %%
imshow(HughJackman_gray[3])

# %% [markdown]
# # B-6 Find out the number of gray_scale img

# %%
len_of_img_WillSmith = len(WillSmith_gray)
len_of_img_WillSmith
# Out:
# 10

# %%
img_size_WillSmith = WillSmith_gray[1].shape
img_size_WillSmith
# Out:
# (512, 512)

# %% [markdown]
# # Flatten size

# %%
flatten_size_WillSmith = img_size_WillSmith[0]*img_size_WillSmith[1]
flatten_size_WillSmith
# Out:
# 262144

# %%
for i in range(len_of_img_WillSmith):
    WillSmith_gray[i] = np.ndarray.flatten(WillSmith_gray[i]).reshape(flatten_size_WillSmith,1)

# %%
np.ndarray.flatten
# Out:
# <method 'flatten' of 'numpy.ndarray' objects>

# %%
WillSmith_gray = np.dstack(WillSmith_gray)
WillSmith_gray
# Out:
# array([[[0.14647299, 0.53181703, 0.33443042, ..., 0.16107355,
#          0.58649333, 0.4301752 ]],
#
#        [[0.14780955, 0.53139194, 0.33537166, ..., 0.16102464,
#          0.58649333, 0.4301752 ]],
#
#        [[0.13778542, 0.53458013, 0.32831234, ..., 0.16139146,
#          0.58649333, 0.4301752 ]],
#
#        ...,
#
#        [[0.02083648, 0.3334668 , 0.22541225, ..., 0.99046237,
#          0.80069986, 0.19972023]],
#
#        [[0.02083648, 0.33211684, 0.22541225, ..., 0.99046237,
#          0.79297758, 0.20204674]],
#
#        [[0.02083648, 0.33229684, 0.22541225, ..., 0.99046237,
#          0.79400722, 0.20173654]]])

# %%
WillSmith_gray.shape
# Out:
# (262144, 1, 10)

# %%
WillSmith_gray = np.rollaxis(WillSmith_gray,axis=2,start=0)
WillSmith_gray.shape
# Out:
# (10, 262144, 1)

# %%
WillSmith_gray = WillSmith_gray.reshape(len_of_img_WillSmith,flatten_size_WillSmith)
WillSmith_gray.shape
# Out:
# (10, 262144)

# %%
WillSmith_data = pd.DataFrame(WillSmith_gray)

# %%
WillSmith_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.146473  0.147810  0.137785  0.122522  0.095035  0.072062  0.071660
# 1  0.531817  0.531392  0.534580  0.537915  0.541591  0.545186  0.548375
# 2  0.334430  0.335372  0.328312  0.325166  0.331150  0.337056  0.342571
# 3  0.003209  0.003314  0.002530  0.001849  0.001409  0.001042  0.001042
# 4  0.114056  0.114559  0.110786  0.106273  0.100032  0.094007  0.089068
# 5  0.167884  0.166214  0.178743  0.191443  0.204541  0.213992  0.205216
# 6  0.203240  0.205909  0.185890  0.179424  0.204585  0.224991  0.221622
# 7  0.161074  0.161025  0.161391  0.162508  0.165375  0.166508  0.158970
# 8  0.586493  0.586493  0.586493  0.586640  0.587128  0.587760  0.589110
# 9  0.430175  0.430175  0.430175  0.430175  0.430175  0.430175  0.430175
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.071112  0.066344  0.061576  ...  0.021252  0.021252  0.021252  0.021252
# ...

# %%
WillSmith_data["Label"] = "WillSmith"
WillSmith_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.146473  0.147810  0.137785  0.122522  0.095035  0.072062  0.071660
# 1  0.531817  0.531392  0.534580  0.537915  0.541591  0.545186  0.548375
# 2  0.334430  0.335372  0.328312  0.325166  0.331150  0.337056  0.342571
# 3  0.003209  0.003314  0.002530  0.001849  0.001409  0.001042  0.001042
# 4  0.114056  0.114559  0.110786  0.106273  0.100032  0.094007  0.089068
# 5  0.167884  0.166214  0.178743  0.191443  0.204541  0.213992  0.205216
# 6  0.203240  0.205909  0.185890  0.179424  0.204585  0.224991  0.221622
# 7  0.161074  0.161025  0.161391  0.162508  0.165375  0.166508  0.158970
# 8  0.586493  0.586493  0.586493  0.586640  0.587128  0.587760  0.589110
# 9  0.430175  0.430175  0.430175  0.430175  0.430175  0.430175  0.430175
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.071112  0.066344  0.061576  ...  0.021252  0.021252  0.021252  0.021252
# ...

# %% [markdown]
# # For Hugh Jackman

# %%
len_of_img_HughJackman = len(HughJackman_gray)
len_of_img_HughJackman
# Out:
# 10

# %%
img_size_HughJackman = HughJackman_gray[1].shape
img_size_HughJackman
# Out:
# (512, 512)

# %%
flatten_size_HughJackman = img_size_HughJackman[0]*img_size_HughJackman[1]
flatten_size_HughJackman
# Out:
# 262144

# %%
for i in range(len_of_img_HughJackman):
    HughJackman_gray[i] = np.ndarray.flatten(HughJackman_gray[i]).reshape(flatten_size_HughJackman,1)

# %%
np.ndarray.flatten
# Out:
# <method 'flatten' of 'numpy.ndarray' objects>

# %%
HughJackman_gray = np.dstack(HughJackman_gray)
HughJackman_gray
# Out:
# array([[[0.30845931, 0.2618898 , 0.6730004 , ..., 0.95402417,
#          0.63466301, 0.05089206]],
#
#        [[0.31030128, 0.2618898 , 0.67296506, ..., 0.95551161,
#          0.63465478, 0.04758215]],
#
#        [[0.29648651, 0.2618898 , 0.67323013, ..., 0.94435582,
#          0.63471649, 0.07240649]],
#
#        ...,
#
#        [[0.97391001, 0.29711683, 0.85685126, ..., 0.95045608,
#          0.43789533, 0.78064803]],
#
#        [[0.97538692, 0.30398149, 0.84725223, ..., 0.95045608,
#          0.43470714, 0.78943709]],
#
#        [[0.97519   , 0.3030662 , 0.8485321 , ..., 0.95045608,
#          0.43513223, 0.78826522]]])

# %%
HughJackman_gray.shape
# Out:
# (262144, 1, 10)

# %%
HughJackman_gray = np.rollaxis(HughJackman_gray,axis=2,start=0)
HughJackman_gray.shape
# Out:
# (10, 262144, 1)

# %%
HughJackman_gray = HughJackman_gray.reshape(len_of_img_HughJackman,flatten_size_HughJackman)
HughJackman_gray.shape
# Out:
# (10, 262144)

# %%
HughJackman_data = pd.DataFrame(HughJackman_gray)

# %%
HughJackman_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.308459  0.310301  0.296487  0.281415  0.263413  0.246102  0.232247
# 1  0.261890  0.261890  0.261890  0.261804  0.261517  0.260987  0.259239
# 2  0.673000  0.672965  0.673230  0.672864  0.671026  0.669494  0.669494
# 3  0.135545  0.134279  0.143780  0.153445  0.163492  0.172793  0.178371
# 4  0.166180  0.167139  0.159946  0.151603  0.140573  0.130093  0.122360
# 5  0.119473  0.119228  0.121066  0.122353  0.122353  0.121981  0.119751
# 6  0.745420  0.750325  0.713532  0.682770  0.666083  0.653382  0.660620
# 7  0.954024  0.955512  0.944356  0.939459  0.949167  0.958987  0.969361
# 8  0.634663  0.634655  0.634716  0.634523  0.633732  0.633820  0.638300
# 9  0.050892  0.047582  0.072406  0.101311  0.139738  0.175377  0.197085
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.218476  0.207136  0.195797  ...  0.970017  0.968612  0.967207  0.967892
# ...

# %%
HughJackman_data["Label"] = "HughJackman"
HughJackman_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.308459  0.310301  0.296487  0.281415  0.263413  0.246102  0.232247
# 1  0.261890  0.261890  0.261890  0.261804  0.261517  0.260987  0.259239
# 2  0.673000  0.672965  0.673230  0.672864  0.671026  0.669494  0.669494
# 3  0.135545  0.134279  0.143780  0.153445  0.163492  0.172793  0.178371
# 4  0.166180  0.167139  0.159946  0.151603  0.140573  0.130093  0.122360
# 5  0.119473  0.119228  0.121066  0.122353  0.122353  0.121981  0.119751
# 6  0.745420  0.750325  0.713532  0.682770  0.666083  0.653382  0.660620
# 7  0.954024  0.955512  0.944356  0.939459  0.949167  0.958987  0.969361
# 8  0.634663  0.634655  0.634716  0.634523  0.633732  0.633820  0.638300
# 9  0.050892  0.047582  0.072406  0.101311  0.139738  0.175377  0.197085
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.218476  0.207136  0.195797  ...  0.968612  0.967207  0.967892  0.968649
# ...

# %% [markdown]
# # For Megan Fox

# %%
len_of_img_MeganFox = len(MeganFox_gray)
len_of_img_MeganFox
# Out:
# 10

# %%
img_size_MeganFox = MeganFox_gray[1].shape
img_size_MeganFox
# Out:
# (512, 512)

# %%
flatten_size_MeganFox = img_size_MeganFox[0]*img_size_MeganFox[1]
flatten_size_MeganFox
# Out:
# 262144

# %%
for i in range(len_of_img_MeganFox):
    MeganFox_gray[i] = np.ndarray.flatten(MeganFox_gray[i]).reshape(flatten_size_MeganFox,1)

# %%
np.ndarray.flatten
# Out:
# <method 'flatten' of 'numpy.ndarray' objects>

# %%
MeganFox_gray = np.dstack(MeganFox_gray)
MeganFox_gray
# Out:
# array([[[0.13232827, 0.19976927, 0.1846374 , ..., 0.22707673,
#          0.06602676, 0.09469615]],
#
#        [[0.13419332, 0.2035716 , 0.18452251, ..., 0.22691206,
#          0.06651696, 0.09500635]],
#
#        [[0.12020549, 0.17505411, 0.18538418, ..., 0.22814712,
#          0.06284049, 0.09267984]],
#
#        ...,
#
#        [[0.53317451, 0.20283405, 0.63571343, ..., 0.23878748,
#          0.05331621, 0.08101229]],
#
#        [[0.51404538, 0.21323157, 0.63019873, ..., 0.21868178,
#          0.05380449, 0.0833388 ]],
#
#        [[0.51659593, 0.21184523, 0.63093402, ..., 0.22136254,
#          0.05373939, 0.0830286 ]]])

# %%
MeganFox_gray.shape
# Out:
# (262144, 1, 10)

# %%
MeganFox_gray = np.rollaxis(MeganFox_gray,axis=2,start=0)
MeganFox_gray.shape
# Out:
# (10, 262144, 1)

# %%
MeganFox_gray = MeganFox_gray.reshape(len_of_img_MeganFox,flatten_size_MeganFox)
MeganFox_gray.shape
# Out:
# (10, 262144)

# %%
MeganFox_data = pd.DataFrame(MeganFox_gray)

# %%
MeganFox_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.132328  0.134193  0.120205  0.113275  0.122811  0.133984  0.153343
# 1  0.199769  0.203572  0.175054  0.148547  0.126731  0.108069  0.105179
# 2  0.184637  0.184523  0.185384  0.183376  0.174674  0.167033  0.164707
# 3  0.071832  0.072257  0.069069  0.066829  0.066801  0.071148  0.097372
# 4  0.179453  0.180089  0.175321  0.169114  0.159550  0.150086  0.141124
# 5  0.073667  0.072760  0.079562  0.088844  0.103913  0.119038  0.134445
# 6  0.073699  0.075432  0.062436  0.053374  0.053489  0.056466  0.073757
# 7  0.227077  0.226912  0.228147  0.228764  0.227937  0.224876  0.210641
# 8  0.066027  0.066517  0.062840  0.056631  0.044509  0.033183  0.025830
# 9  0.094696  0.095006  0.092680  0.090500  0.088662  0.086381  0.081888
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.171881  0.166625  0.161369  ...  0.434343  0.421537  0.408731  0.432410
# ...

# %%
MeganFox_data["Label"] = "MeganFox"
MeganFox_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.132328  0.134193  0.120205  0.113275  0.122811  0.133984  0.153343
# 1  0.199769  0.203572  0.175054  0.148547  0.126731  0.108069  0.105179
# 2  0.184637  0.184523  0.185384  0.183376  0.174674  0.167033  0.164707
# 3  0.071832  0.072257  0.069069  0.066829  0.066801  0.071148  0.097372
# 4  0.179453  0.180089  0.175321  0.169114  0.159550  0.150086  0.141124
# 5  0.073667  0.072760  0.079562  0.088844  0.103913  0.119038  0.134445
# 6  0.073699  0.075432  0.062436  0.053374  0.053489  0.056466  0.073757
# 7  0.227077  0.226912  0.228147  0.228764  0.227937  0.224876  0.210641
# 8  0.066027  0.066517  0.062840  0.056631  0.044509  0.033183  0.025830
# 9  0.094696  0.095006  0.092680  0.090500  0.088662  0.086381  0.081888
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.171881  0.166625  0.161369  ...  0.421537  0.408731  0.432410  0.457346
# ...

# %% [markdown]
# # Merge Imgs

# %%
man_1=pd.concat([WillSmith_data,MeganFox_data])

# %%
man=pd.concat([man_1,HughJackman_data])

# %%
man
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.146473  0.147810  0.137785  0.122522  0.095035  0.072062  0.071660
# 1  0.531817  0.531392  0.534580  0.537915  0.541591  0.545186  0.548375
# 2  0.334430  0.335372  0.328312  0.325166  0.331150  0.337056  0.342571
# 3  0.003209  0.003314  0.002530  0.001849  0.001409  0.001042  0.001042
# 4  0.114056  0.114559  0.110786  0.106273  0.100032  0.094007  0.089068
# 5  0.167884  0.166214  0.178743  0.191443  0.204541  0.213992  0.205216
# 6  0.203240  0.205909  0.185890  0.179424  0.204585  0.224991  0.221622
# 7  0.161074  0.161025  0.161391  0.162508  0.165375  0.166508  0.158970
# 8  0.586493  0.586493  0.586493  0.586640  0.587128  0.587760  0.589110
# 9  0.430175  0.430175  0.430175  0.430175  0.430175  0.430175  0.430175
# 0  0.132328  0.134193  0.120205  0.113275  0.122811  0.133984  0.153343
# 1  0.199769  0.203572  0.175054  0.148547  0.126731  0.108069  0.105179
# ...

# %% [markdown]
# # Shuffling

# %%
from sklearn.utils import shuffle

# %%
fb_indexed=shuffle(man).reset_index()
fb_indexed
# Out:
#     index         0         1         2         3         4         5  \
# 0       0  0.132328  0.134193  0.120205  0.113275  0.122811  0.133984
# 1       2  0.673000  0.672965  0.673230  0.672864  0.671026  0.669494
# 2       2  0.334430  0.335372  0.328312  0.325166  0.331150  0.337056
# 3       7  0.161074  0.161025  0.161391  0.162508  0.165375  0.166508
# 4       3  0.071832  0.072257  0.069069  0.066829  0.066801  0.071148
# 5       1  0.261890  0.261890  0.261890  0.261804  0.261517  0.260987
# 6       6  0.073699  0.075432  0.062436  0.053374  0.053489  0.056466
# 7       4  0.166180  0.167139  0.159946  0.151603  0.140573  0.130093
# 8       9  0.430175  0.430175  0.430175  0.430175  0.430175  0.430175
# 9       0  0.308459  0.310301  0.296487  0.281415  0.263413  0.246102
# 10      7  0.954024  0.955512  0.944356  0.939459  0.949167  0.958987
# 11      3  0.003209  0.003314  0.002530  0.001849  0.001409  0.001042
# ...

# %%
fb_man=fb_indexed.drop(['index'],axis=1)

# %%
fb_man.to_csv("Players.csv")

# %%
x = fb_man.values[:,:-1]

# %%
y = fb_man.values[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (24, 262144)

# %%
x_test.shape
# Out:
# (6, 262144)

# %% [markdown]
# # Decomposition

# %%
from sklearn import decomposition

# %%
pca = decomposition.PCA(n_components=20, whiten=True, random_state=1)

# %% [markdown]
# # D5 Fitting Training Set

# %%
pca.fit(x_train)
# Out:
# PCA(n_components=20, random_state=1, whiten=True)

# %% [markdown]
# # D6 Change Train set

# %%
x_train_pca = pca.transform(x_train)
x_test_pca = pca.transform(x_test)

# %%
x_train_pca.shape
# Out:
# (24, 20)

# %%
x_test_pca.shape
# Out:
# (6, 20)

# %% [markdown]
# # D7- viewing the priciple components or eigen faces

# %%
eigen = (np.reshape(x[10],(512,512)).astype(np.float64))

# %%
eigen
# Out:
# array([[0.95402417, 0.95551161, 0.94435582, ..., 0.93927961, 0.93927961,
#         0.93927961],
#        [0.95335781, 0.95505971, 0.94229546, ..., 0.93927961, 0.93927961,
#         0.93927961],
#        [0.95835551, 0.95844896, 0.95774813, ..., 0.93927961, 0.93927961,
#         0.93927961],
#        ...,
#        [0.97821255, 0.97821255, 0.97821255, ..., 0.95045608, 0.95045608,
#         0.95045608],
#        [0.97821255, 0.97821255, 0.97821255, ..., 0.95045608, 0.95045608,
#         0.95045608],
#        [0.97821255, 0.97821255, 0.97821255, ..., 0.95045608, 0.95045608,
#         0.95045608]])

# %% [markdown]
# # D7.2 plotting

# %%
fig = plt.figure(figsize=(30,30))
for i in range(10):
    ax = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
    ax.imshow(pca.components_[i].reshape(eigen.shape),cmap=plt.cm.bone)
